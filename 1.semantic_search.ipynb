# %%
from dotenv import load_dotenv
import os,json 
from openai import AzureOpenAI
import psycopg2
from psycopg2.extras import execute_values
from pgvector.psycopg2 import register_vector
import numpy as np

load_dotenv()
# Out:
# True

# %%
## Intializing connection and Creating a Table


 
DBUSER = os.environ["DBUSER"]
DBPASS = os.environ["DBPASS"]
DBHOST = os.environ["DBHOST"]
DBNAME = os.environ["DBNAME"]
# Use SSL if not connecting to localhost
DBSSL = "disable"
if DBHOST != "localhost":
    DBSSL = "require"
 
 
## initiate a connection
 
def initiate_connection():
    conn = psycopg2.connect(database=DBNAME, user=DBUSER, password=DBPASS, host=DBHOST, sslmode=DBSSL,port=38530)
    conn.autocommit = True
    return conn
 
 
def create_table(conn,table_name):
    cur = conn.cursor()
    cur.execute("CREATE EXTENSION IF NOT EXISTS vector")
    cur.execute(f"DROP TABLE IF EXISTS {table_name}")
    cur.execute(f"CREATE TABLE {table_name} (id bigserial PRIMARY KEY, text TEXT, embedding VECTOR(1536));")
    register_vector(conn)
 
 
 
## initialize a connection
conn = initiate_connection()
## Register the vector type with psycopg2
register_vector(conn)
## create a table
create_table(conn,table_name="bio_data")

# %% [markdown]
# ### Preprocessing the text

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
 
doc_path = "data/messi.pdf"
 
# load your pdf doc
loader = PyPDFLoader(doc_path)
pages = loader.load()
 
 
# split the doc into smaller chunks i.e. chunk_size=500
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
chunks = text_splitter.split_documents(pages)

# %%
for chunk in chunks:
    print(chunk)
# Out:
# page_content='Lionel\xa0Messi:\xa0A\xa0Biography\xa0\n\xa0\n\xa0\nLionel\xa0Messi\xa0is\xa0a\xa0professional\xa0footballer\xa0who\xa0plays\xa0for\xa0the\xa0Spanish\xa0football\xa0team,\xa0FC\xa0\nBarcelona.\xa0He\xa0wears\xa0the\xa0number\xa010\xa0shirt\xa0for\xa0his\xa0club\xa0and\xa0for\xa0his\xa0national\xa0team,\xa0Argentina.\xa0\nAlso,\xa0he\xa0is\xa0widely\xa0regarded\xa0as\xa0the\xa0best\xa0player\xa0of\xa0all\xa0time,\xa0along\xa0with\xa0Cristiano\xa0Ronaldo,\xa0and\xa0\nthe\xa0now\xadretired\xa0footballers,\xa0Pele\xa0and\xa0Diego\xa0Maradona.\xa0Read\xa0on\xa0to\xa0find\xa0out\xa0more\xa0about\xa0this\xa0\nspectacular\xa0footballer.\xa0\n\xa0\nChildhood' metadata={'source': 'data/messi.pdf', 'page': 0}
# page_content='spectacular\xa0footballer.\xa0\n\xa0\nChildhood\xa0\nLionel\xa0Messi\xa0was\xa0born\xa0on\xa024\xa0June\xa01987\xa0in\xa0the\xa0small\xa0town\xa0of\xa0Rosario,\xa0Argentina.\xa0His\xa0\nmother\xa0is\xa0called\xa0Celia\xa0Cuccitini,\xa0and\xa0his\xa0father\xa0is\xa0called\xa0Jorge\xa0Messi.\xa0Celia\xa0was\xa0a\xa0magnet\xa0\nmanufacturer\xa0and\xa0Jorge\xa0was\xa0a\xa0steel\xa0factory\xa0worker.\xa0Lionel\xa0is\xa0the\xa03rd\xa0oldest\xa0of\xa04\xa0children\xa0in\xa0\nhis\xa0family.\xa0His\xa0two\xa0older\xa0brothers\xa0are\xa0called\xa0Rodrigo\xa0and\xa0Matias\xa0(both\xa0of\xa0whom\xa0are\xa0also\xa0\nprofessional\xa0footballers)\xa0and\xa0a\xa0younger\xa0sister\xa0called\xa0Maria\xa0Sol.\xa0He\xa0played\xa0for\xa0a\xa0children’s' metadata={'source': 'data/messi.pdf', 'page': 0}
# page_content='football\xa0club\xa0and\xa0became\xa0the\xa0star\xa0of\xa0the\xa0team\xa0very\xa0quickly,\xa0becoming\xa0part\xa0of\xa0their\xa0best\xa0\nseason’s\xa0team,\xa0and\xa0joined\xa0the\xa0Machine\xa0of\xa0‘87\xa0(the\xa0club’s\xa0best\xa0team).\xa0Unfortunately,\xa0at\xa0the\xa0\nage\xa0of\xa011,\xa0he\xa0was\xa0diagnosed\xa0with\xa0GHD\xa0(growth\xa0hormone\xa0deficiency).\xa0Not\xa0even\xa0River\xa0Plate,\xa0\nthe\xa0country’s\xa0richest\xa0team\xa0at\xa0the\xa0time,\xa0would\xa0(or\xa0could)\xa0pay\xa0for\xa0the\xa0treatment\xa0due\xa0to\xa0\nArgentina’s\xa0economic\xa0collapse.\xa0This\xa0deficiency\xa0severely\xa0affected\xa0his\xa0football\xa0life\xa0and\xa0could\xa0\nhave\xa0eventually\xa0ended\xa0it.' metadata={'source': 'data/messi.pdf', 'page': 0}
# page_content='have\xa0eventually\xa0ended\xa0it.\xa0\n\xa0\nOne\xa0day,\xa0Charly\xa0Rexach,\xa0the\xa0manager\xa0of\xa0FC\xa0Barcelona\xa0at\xa0the\xa0time,\xa0said\xa0to\xa0Messi\xa0\nand\xa0his\xa0family\xa0that\xa0the\xa0team\xa0could\xa0pay\xa0for\xa0his\xa0growth\xa0hormone\xa0treatment.\xa0Additionally,\xa0with\xa0\nno\xa0other\xa0paper\xa0at\xa0hand,\xa0he\xa0offered\xa0Lionel\xa0a\xa0youth\xa0team\xa0contract\xa0on\xa0a\xa0paper\xa0napkin!\xa0His\xa0only\xa0\ncondition\xa0was\xa0that\xa0Messi’s\xa0family\xa0should\xa0move\xa0to\xa0Spain.\xa0Delighted,\xa0they\xa0agreed\xa0almost\xa0\ninstantly.\xa0\n\xa0\nA\xa0few\xa0weeks\xa0later,\xa0Messi\xa0and\xa0his\xa0family\xa0relocated\xa0to\xa0Spain.\xa0Right\xa0from\xa0Lionel\xa0Messi’s' metadata={'source': 'data/messi.pdf', 'page': 0}
# page_content='first\xa0game\xa0for\xa0the\xa0youth\xa0team,\xa0he\xa0had\xa0already\xa0established\xa0himself\xa0as\xa0a\xa0young\xa0prodigy\xa0and\xa0\nwas\xa0recognized\xa0by\xa0many\xa0fans.\xa0He\xa0was\xa0always\xa0one\xa0of\xa0the\xa0best\xa0players\xa0for\xa0the\xa0youth\xa0squad.\xa0\nUnfortunately,\xa0Messi\xa0suffered\xa0from\xa0homesickness\xa0often\xa0because\xa0his\xa0mum\xa0and\xa0his\xa0siblings\xa0\nmoved\xa0back\xa0to\xa0Argentina\xa0a\xa0year\xa0after\xa0they\xa0moved\xa0in\xa0the\xa0first\xa0place.\xa0Only\xa0Messi\xa0and\xa0his\xa0father\xa0\nstayed\xa0in\xa0Spain.\xa0Did\xa0you\xa0know\xa0that\xa0Messi\xa0was\xa0so\xa0quiet,\xa0his\xa0teammates\xa0initially\xa0believed\xa0he\xa0\nwas\xa0mute\xa0(can’t\xa0speak)?\xa0\n\xa0\nEarly\xa0Career' metadata={'source': 'data/messi.pdf', 'page': 0}
# page_content='was\xa0mute\xa0(can’t\xa0speak)?\xa0\n\xa0\nEarly\xa0Career\xa0\n\xa0\nNear\xa0the\xa0start\xa0of\xa0the\xa02003\xad04\xa0season,\xa0Messi\xa0started\xa0his\xa0first\xa0senior\xa0squad\xa0game.\xa0\nUnfortunately,\xa0he\xa0didn’t\xa0score\xa0any\xa0goals\xa0in\xa0that\xa0match.\xa0He\xa0quickly\xa0became\xa0Barcelona’s\xa0first\xa0\nchoice\xa0winger,\xa0forming\xa0an\xa0astounding\xa0attacking\xa0trio\xa0with\xa0Ronaldinho\xa0and\xa0Samuel\xa0Eto’o.\xa0In\xa0\nthe\xa0return\xa0leg\xa0against\xa0Chelsea\xa0in\xa0the\xa0Round\xa0of\xa016\xa0in\xa0the\xa0Champions\xa0League,\xa0Messi\xa0suffered\xa0\na\xa0hamstring\xa0injury.\xa0He\xa0worked\xa0hard\xa0to\xa0recover,\xa0but\xa0on\xa0the\xa0day\xa0of\xa0the\xa0Champions\xa0League' metadata={'source': 'data/messi.pdf', 'page': 0}
# page_content='Final,\xa0he\xa0was\xa0told\xa0that\xa0he\xa0couldn’t\xa0play.\xa0He\xa0was\xa0so\xa0disappointed\xa0that\xa0he\xa0didn’t\xa0celebrate\xa0\nBarcelona’s\xa0win\xa0against\xa0Arsenal\xa0in\xa0Paris,\xa0something\xa0he\xa0later\xa0came\xa0to\xa0regret.' metadata={'source': 'data/messi.pdf', 'page': 0}
# page_content='Pro\xa0Career\xa0\n\xa0\nMessi,\xa0who\xa0was\xa0still\xa0quite\xa0young\xa0at\xa0the\xa0time,\xa0was\xa0always\xa0compared\xa0to\xa0fellow\xa0\nArgentine,\xa0Diego\xa0Maradona.\xa0On\xa018\xa0April\xa02007,\xa0Messi\xa0scored\xa0a\xa0goal\xa0remarkably\xa0similar\xa0to\xa0\nMaradona.\xa0On\xa09\xa0June\xa0of\xa0the\xa0same\xa0year,\xa0Messi\xa0scored\xa0his\xa0own\xa0Hand\xa0of\xa0God\xa0goal,\xa0again\xa0\nsimilar\xa0to\xa0Maradona.\xa0Soon\xa0after,\xa0Lionel\xa0became\xa0Barca’s\xa0new\xa0star\xa0at\xa0the\xa0young\xa0age\xa0of\xa020.\xa0His\xa0\nefforts\xa0in\xa02007\xa0led\xa0him\xa0to\xa0be\xa0voted\xa03rd\xa0place\xa0for\xa0the\xa0Ballon\xa0d’Or\xa0behind\xa0Kaka,\xa0and\xa0runner\xadup' metadata={'source': 'data/messi.pdf', 'page': 1}
# page_content='Cristiano\xa0Ronaldo.\xa0Barcelona\xa0finished\xa0the\xa0season\xa0without\xa0any\xa0trophies.\xa0\n\xa0\nAhead\xa0of\xa0the\xa0new\xa0season,\xa0one\xa0concern\xa0was\xa0about\xa0Messi’s\xa0frequent\xa0muscular\xa0\ninjuries.\xa0To\xa0combat\xa0this,\xa0the\xa0club\xa0implemented\xa0new\xa0regimens,\xa0and\xa0assigned\xa0Messi\xa0a\xa0\npersonal\xa0physiotherapist.\xa0As\xa0a\xa0result,\xa0Messi\xa0stayed\xa0uninjured\xa0for\xa04\xa0years.\xa0His\xa0performances\xa0\nin\xa02008\xa0led\xa0him\xa0to\xa0be\xa0runner\xadup\xa0for\xa0the\xa0Ballon\xa0d’Or,\xa0behind\xa0Cristiano\xa0Ronaldo\xa0again.' metadata={'source': 'data/messi.pdf', 'page': 1}
# page_content='Eventually,\xa0at\xa022\xa0years\xa0old,\xa0Messi\xa0won\xa0his\xa0first\xa0Ballon\xa0d’Or.\xa0He\xa0has\xa0won\xa04\xa0FIFA\xa0Ballon\xa0d’Or’s\xa0\n(these\xa0are\xa0the\xa0new\xa0ones)\xa0in\xa02010,\xa02011,\xa02012\xa0and\xa02015.\xa0\n\xa0\nA\xa0few\xa0years\xa0later,\xa0in\xa02016,\xa0Messi\xa0scored\xa0Barcelona’s\xa010,000th\xa0goal\xa0overall\xa0in\xa0a\xa02\xad0\xa0\nwin\xa0against\xa0Arsenal\xa0in\xa0the\xa0Champions\xa0League.\xa0\n\xa0\nOverall,\xa0Messi\xa0has\xa0won\xa0these\xa0trophies:\xa07\xa0La\xa0Liga’s,\xa03\xa0Copa\xa0del\xa0Rey’s,\xa06\xa0Supercopa\xa0\nde\xa0Espanas,\xa04\xa0UEFA\xa0Champions\xa0Leagues,\xa03\xa0UEFA\xa0Super\xa0Cups\xa0and\xa03\xa0FIFA\xa0Club\xa0World\xa0\nCups.\xa0\n\xa0\nLegacy' metadata={'source': 'data/messi.pdf', 'page': 1}
# page_content='Cups.\xa0\n\xa0\nLegacy\xa0\n\xa0\nMessi\xa0plans\xa0to\xa0gain\xa0much\xa0more\xa0trophies,\xa0with\xa0Barcelona\xa0and\xa0individual,\xa0and\xa0also\xa0to\xa0win\xa0the\xa0\nFIFA\xa0World\xa0Cup\xa0with\xa0his\xa0country,\xa0Argentina,\xa0like\xa0Diego\xa0Maradona,\xa0his\xa0fellow\xa0compatriot.' metadata={'source': 'data/messi.pdf', 'page': 1}

# %% [markdown]
# ### Create OpenAI Embeddings

# %%
client = AzureOpenAI(api_key=os.getenv("OPENAI_API_KEY"),
                    api_version=os.getenv("OPENAI_API_VERSION"),
                        azure_endpoint = os.getenv("OPENAI_API_ENDPOINT")
    )

def get_embeddings(text,client):
   """
   creates openai embedding
   """
   response = client.embeddings.create(
       model = 'text-embedding-ada-002',
       input=text
   )
   response = response.json()
   embedding = json.loads(response)
   return embedding["data"][0]["embedding"]


##example
emb = get_embeddings(chunks[0].page_content,client)
print(emb)
# Out:
# [-0.00980521272867918, 0.023951852694153786, 0.007665333338081837, -0.016675028949975967, -0.0018623737851157784, 0.021275462582707405, -0.024112191051244736, 0.015750009566545486, -0.01081656850874424, -0.03246203809976578, 0.010051884688436985, 0.019869431853294373, -0.005198612809181213, -0.007541996892541647, -0.0017344126245006919, 0.011562750674784184, 0.023729847744107246, 0.003878917545080185, 0.012142430059611797, 1.480273022025358e-05, -0.005130778066813946, 0.009780545718967915, 0.008615020662546158, -0.0018839575350284576, -0.016675028949975967, -0.008701355196535587, 0.02550588734447956, -0.010717899538576603, 0.03268404304981232, -0.006666311528533697, 0.013258621096611023, -0.0024543865583837032, -0.002953897463157773, -0.018315397202968597, -0.01610768400132656, -0.0035058262292295694, -0.00119790097232908, -0.022854162380099297, 0.017279375344514847, -0.002258590655401349, 0.030932672321796417, 0.025555221363902092, -0.0231008343398571, -0.00018577487207949162, -0.0069376504980027676, 0.012006760574877262, 0.008417682722210884, -0.03221536800265312, -0.024062855169177055, 0.014578316360712051, 0.01940075494349003, 0.0026378489565104246, -0.009891548193991184, -0.02720792405307293, -0.021337129175662994, -0.04151490330696106, -0.015565005131065845, -0.018747074529528618, 0.02364351414144039, -0.017723385244607925, 0.007640665862709284, 0.00019868661183863878, -0.00328382127918303, -0.0068698157556355, 0.004585016053169966, -0.013936969451606274, -0.009817546233534813, 0.01698336936533451, -0.005167779047042131, 0.03497809171676636, 0.03527409955859184, 0.02120145969092846, 0.004221174865961075, 0.0021152126137167215, 0.023902518674731255, 0.002435886301100254, -0.02703525312244892, -0.011840256862342358, 0.006228468380868435, 0.004776187241077423, 0.01463998481631279, -0.026344571262598038, 0.0040885889902710915, 0.016033681109547615, 0.02435886301100254, -0.014898990280926228, 0.01256177294999361, 0.006690978538244963, -0.03359672799706459, 0.005584037862718105, 0.0001583133271196857, -0.00416567362844944, 0.019696760922670364, -0.020991789177060127, -0.026418574154376984, 0.0008032257901504636, 0.0107919005677104, 0.013875300996005535, 0.010113553144037724, -0.027479263022542, 0.004884106107056141, -0.011649086140096188, -0.01938842050731182, -0.006734146270900965, -0.007690000347793102, -0.013801299966871738, -0.012530938722193241, 0.0035613272339105606, 0.03670479729771614, -0.0007619853131473064, 0.0015763883711770177, 0.020387442782521248, 0.03418874368071556, -0.050173088908195496, 0.002374218311160803, -0.015799343585968018, 0.03423807770013809, -0.011840256862342358, 0.009287201799452305, -0.014331644400954247, 0.02229915000498295, 0.03108067438006401, 0.019746094942092896, -0.04015820473432541, 0.013751965016126633, 0.0028521453496068716, -0.014565982855856419, -0.03194402530789375, -0.014701652340590954, -0.0007404015050269663, 0.012068429030478, 0.009355036541819572, -0.0184017326682806, 0.011217410676181316, 0.011439414694905281, -0.021374130621552467, 0.0006972338887862861, -0.0019348337082192302, 0.009540040045976639, -0.030291324481368065, 0.011938925832509995, 0.006641644053161144, -0.023396842181682587, -0.014282310381531715, -0.01916641555726528, 0.050395093858242035, 0.012037594802677631, 0.016132351011037827, -0.004742269869893789, 0.014837321825325489, 0.037617482244968414, 0.02932930365204811, 0.023236503824591637, -0.014380979351699352, 0.007443328388035297, -0.0015972013352438807, 0.007295324932783842, 0.011476416140794754, -0.016909366473555565, -0.029156632721424103, 0.005442201625555754, -0.003986836411058903, -0.011513416655361652, -0.0015170329716056585, 0.014282310381531715, 0.04042954370379448, 0.0022107979748398066, 0.009521540254354477, -0.005849210545420647, 0.020769784227013588, 0.007258324418216944, 0.014590649865567684, -0.019918765872716904, 0.038530170917510986, 0.009361202828586102, 0.013838300481438637, 0.0198324304074049, 0.0090405298396945, -0.015120995230972767, 0.01 ...

# %% [markdown]
# ### Inject Embeddings and Text to Database

# %%
register_vector(conn)
cur = conn.cursor()

## list of tuples to be inserted
data = [(chunk.page_content,get_embeddings(chunk.page_content,client)) for chunk in chunks]
## use execute_values for batch insertion
execute_values(cur,"INSERT INTO bio_data (text,embedding) VALUES %s",data)

# Commit after we insert all embeddings
conn.commit()

# %% [markdown]
# **Lets see total number of rows in database**

# %%
cur = conn.cursor()

## print total number of records in the table
cur.execute("SELECT COUNT(*) as cnt FROM bio_data")
num_records = cur.fetchone()[0]
print("Total number of records inserted: ",num_records)

# print the first record in the table, for sanity-checking
cur.execute("SELECT * FROM bio_data LIMIT 1;")
records = cur.fetchall()
print("First record in table: ", records)
# Out:
# Total number of records inserted:  11
# First record in table:  [(1, 'Lionel\xa0Messi:\xa0A\xa0Biography\xa0\n\xa0\n\xa0\nLionel\xa0Messi\xa0is\xa0a\xa0professional\xa0footballer\xa0who\xa0plays\xa0for\xa0the\xa0Spanish\xa0football\xa0team,\xa0FC\xa0\nBarcelona.\xa0He\xa0wears\xa0the\xa0number\xa010\xa0shirt\xa0for\xa0his\xa0club\xa0and\xa0for\xa0his\xa0national\xa0team,\xa0Argentina.\xa0\nAlso,\xa0he\xa0is\xa0widely\xa0regarded\xa0as\xa0the\xa0best\xa0player\xa0of\xa0all\xa0time,\xa0along\xa0with\xa0Cristiano\xa0Ronaldo,\xa0and\xa0\nthe\xa0now\xadretired\xa0footballers,\xa0Pele\xa0and\xa0Diego\xa0Maradona.\xa0Read\xa0on\xa0to\xa0find\xa0out\xa0more\xa0about\xa0this\xa0\nspectacular\xa0footballer.\xa0\n\xa0\nChildhood', array([-0.00980521,  0.02395185,  0.00766533, ..., -0.03130268,
#         0.00775167, -0.0247412 ], dtype=float32))]

# %% [markdown]
# ### Indexing For Faster Data Retrieval
#
#
# * Here we have only few embedding vectors.so the vector search would be very fast. But what if we have large corpus of data. For large datasets, we create indexes to speed up searching for similar embeddings.
#
# * Pgvector supports the ivfflat index type to provide for speed up of approximate nearest neighbor (ANN) searches.
#
# * We always want to build this index after you have inserted the data, as the index needs to discover clusters in your data to be effective, and it does this only when first building the index.
#
# * For ivfat index we have a tunable parameter, which is  number of lists. We can use the below logic for it. Also we use vector_cosine_ops for creating the index as we use cosine similarity later while fetching the data.

# %%
import math

num_lists = num_records / 1000

if num_lists < 10:
   num_lists = 10
if num_records > 1000000:
   num_lists = math.sqrt(num_records)

print('Appropriate number of lists for our case: ',num_lists)
# Out:
# Appropriate number of lists for our case:  10

# %%
#use the cosine distance measure, which is what we'll later use for querying
cur.execute(f'CREATE INDEX ON bio_data USING ivfflat (embedding vector_cosine_ops) WITH (lists = {num_lists});')
conn.commit()

# %% [markdown]
# ## Retrieval Pipeline
#
#
# **Symbols used for similarity**
#
# ```
# <-> - L2 distance
# <#> - (negative) inner product
# <=> - cosine distance
# <+> - L1 distance (added in 0.7.0)
# ```

# %%
def get_top_similar_docs(query_embedding, conn, n=2):
    embedding_array = np.array(query_embedding)
    # Register pgvector extension
    register_vector(conn)
    cur = conn.cursor()
    # Get the top 3 most similar documents using the KNN <=> operator
    cur.execute(f"SELECT text FROM bio_data ORDER BY embedding <=> %s LIMIT {n}", (embedding_array,))
    top3_docs = cur.fetchall()
    return top3_docs



query = "With which players do messi played attacking role in Barcelona?"
query_embedding = get_embeddings(query,client)
top_text = get_top_similar_docs(query_embedding, conn)
for text in top_text:
    print(text[0])
# Out:
# was mute (can’t speak)?
#
# Early Career
#
# Near the start of the 2003­04 season, Messi started his first senior squad game.
# Unfortunately, he didn’t score any goals in that match. He quickly became Barcelona’s first
# choice winger, forming an astounding attacking trio with Ronaldinho and Samuel Eto’o. In
# the return leg against Chelsea in the Round of 16 in the Champions League, Messi suffered
# a hamstring injury. He worked hard to recover, but on the day of the Champions League
# Cristiano Ronaldo. Barcelona finished the season without any trophies.
#
# Ahead of the new season, one concern was about Messi’s frequent muscular
# injuries. To combat this, the club implemented new regimens, and assigned Messi a
# personal physiotherapist. As a result, Messi stayed uninjured for 4 years. His performances
# in 2008 led him to be runner­up for the Ballon d’Or, behind Cristiano Ronaldo again.

# %%
system_prompt = """You are AI assistant who answers the question from the extracted content from articles.
                    You answer should be concise and clear.
                    You should only answer from given content.
                    If answer is not present or the question is out of context you should give answer as `I dont know`
                    You should not make up any answers.
                    """


def get_open_ai_response(query,content):

    user_prompt = f"""Question: {query} 
                      Content: {content}
                      Answer:"""
    
    messages = [
        {'role':'system','content':system_prompt},
        {'role':'user','content':user_prompt}
    ]

    response = client.chat.completions.create(
          model = 'gpt-4-32k',
          messages = messages,

      )
    
    response = response.json()
    response = json.loads(response)
    return response['choices'][0]['message']['content']



def answer(query):
    query_embedding = get_embeddings(query,client)
    top_text = get_top_similar_docs(query_embedding, conn)
    content = ' '.join([i[0] for i in top_text])
    ans = get_open_ai_response(query,content)
    return ans

# %%
query = "Do messi eat pizza"
print('Query: ',query)
print('Answer: ' ,answer(query))
print('-------'*2)

query = "Childhood club of messi?"
print('Query: ',query)
print('Answer: ' ,answer(query))
print('-------'*2)

query = "write a small note on childhood of messi?"
print('Query: ',query)
print('Answer: ' ,answer(query))
print('-------'*2)
# Out:
# Query:  Do messi eat pizza
# Answer:  I don't know
# --------------
# Query:  Childhood club of messi?
# Answer:  I don't know
# --------------
# Query:  write a small note on childhood of messi?
# Answer:  From a young age, Messi established himself as a prodigy in his youth team, becoming one of the best players. However, he often experienced homesickness when his mother and siblings moved back to Argentina, leaving only him and his father in Spain. Interestingly, Messi was so quiet that his teammates at first thought he was mute.
# --------------
